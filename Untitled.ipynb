# %%
import numpy as np
import pandas as pd
import yfinance as yf
import datetime as dt
import matplotlib.pyplot as plt
import mplfinance as mpf

# %%
start = '2016-01-01'
end = dt.datetime.now()

# %%
stock='AMD'
df = yf.download(stock,start, end, interval='1d')
print(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-12-31   2.970000   3.010000   2.870000   2.870000   2.870000  11086100
# 2016-01-04   2.770000   2.820000   2.630000   2.770000   2.770000  32516800
# 2016-01-05   2.770000   2.800000   2.640000   2.750000   2.750000  12972300
# 2016-01-06   2.660000   2.710000   2.470000   2.510000   2.510000  23759400
# 2016-01-07   2.430000   2.480000   2.260000   2.280000   2.280000  22203500
# ...               ...        ...        ...        ...        ...       ...
# 2021-01-20  90.550003  90.779999  88.599998  88.750000  88.750000  35185800
# 2021-01-21  89.339996  92.070000  88.430000  91.529999  91.529999  54596100
# 2021-01-22  94.419998  95.949997  91.879997  92.790001  92.790001  71294700
# 2021-01-25  94.139999  95.739998  91.400002  94.129997  94.129997  55086900
# 2021-01-26  94.910004  95.720001  93.629997  94.709999  94.709999  58843900
#
# [1276 rows x 6 columns]

# %%
short_sma= 20
long_sma = 50
SMAs=[short_sma, long_sma]

# %%
for i in SMAs:
    df["SMA_"+str(i)]= df.iloc[:,4].rolling(window=i).mean()

# %%
position=0 # 1 means we have already entered poistion, 0 means not already entered
counter=0
percentChange=[]   # empty list to collect %changes 
for i in df.index:
    SMA_short=df['SMA_20']
    SMA_long =df['SMA_50']
    close=df['Adj Close'][i]
    
    if(SMA_short[i] > SMA_long[i]):                          #line 9
        print('Up trend')
        if(position==0):
            buyP=close   #buy price
            position=1   # turn position
            print("Buy at the price"+str(buyP))
        
    elif(SMA_short[i] < SMA_long[i]):
        print('Down trend')
        if(position==1):   # have a poistion in down trend
            position=0     # selling position
            sellP=close    # sell price
            print("Sell at the price"+str(sellP))
            perc=(sellP/buyP-1)*100
            percentChange.append(perc)                      #line 23
    if(counter==df["Adj Close"].count()-1 and position==1):
        position=0
        sellP=close
        print("Sell at the price"+str(sellP))
        perc=(sellP/buyP-1)*100
        percentChange.append(perc)
counter+=1
print(percentChange)
# Out:
# Up trend
# Buy at the price2.7200000286102295
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price6.320000171661377
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price7.5
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price12.789999961853027
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price14.380000114440918
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price12.050000190734863
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price13.229999542236328
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price12.050000190734863
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price12.140000343322754
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price11.8100004196167
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price11.949999809265137
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price22.790000915527344
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price20.18000030517578
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price27.579999923706055
# Up trend
# Buy at the price29.56999969482422
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price30.719999313354492
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price33.029998779296875
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price39.0099983215332
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price56.970001220703125
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price54.22999954223633
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price61.790000915527344
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price81.98999786376953
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price82.0
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price76.58000183105469
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price85.06999969482422
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# [132.3529450435539, 70.53333282470705, -16.20305914577973, -8.919118611715415, -2.718285950358823, 90.71130777640415, 36.66996782270768, 3.8890755170740254, 18.10475253781898, -4.809551728552652, 32.69136858544064, -6.609753864567458]

# %%
gains=0
numGains=0
losses=0
numLosses=0
totReturn=1
for i in percentChange:
    if(i>0):
        gains+=i
        numGains+=1
    else:
        losses+=i
        numLosses+=1
    totReturn = totReturn*((i/100)+1)
totReturn=round((totReturn-1)*100,2)
print("This statistics is from "+str(df.index[0])+" up to now with "+str(numGains+numLosses)+" trades:")
print("SMAs used: "+str(SMAs))
print("Total return over "+str(numGains+numLosses)+ " trades: "+ str(totReturn)+"%" )
# Out:
# This statistics is from 2015-12-31 00:00:00 up to now with 12 trades:
# SMAs used: [20, 50]
# Total return over 12 trades: 1009.86%

# %%
if (numGains>0):
    avgGain=gains/numGains
    maxReturn= str(max(percentChange))
else:
    avgGain=0
    maxReturn='unknown'
if(numLosses>0):
    avgLoss=losses/numLosses
    maxLoss=str(min(percentChange))
    ratioRR=str(-avgGain/avgLoss)  # risk-reward ratio
else:
    avgLoss=0
    maxLoss='unknown'
    ratioRR='inf'
print("Average Gain: "+ str(avgGain))
print("Average Loss: "+ str(avgLoss))
print("Max Return: "+ maxReturn)
print("Max Loss: "+ maxLoss)
print("Gain/loss ratio: "+ ratioRR)

if(numGains>0 or numLosses>0):
    batAvg=numGains/(numGains+numLosses)
else:
    batAvg=0
print("Batting Avg: "+ str(batAvg))
# Out:
# Average Gain: 54.99325001538664
# Average Loss: -7.851953860194816
# Max Return: 132.3529450435539
# Max Loss: -16.20305914577973
# Gain/loss ratio: 7.00376632294961
# Batting Avg: 0.5833333333333334

# %%
mpf.plot(df, type = 'ohlc',figratio=(16,6), 
         mav=(short_sma,long_sma), 
         volume=True, title= str(stock), 
         style='default')
