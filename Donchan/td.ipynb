# %%
import numpy as np
import pandas as pd
import yfinance as yf
import datetime as dt
import matplotlib.pyplot as plt
import mplfinance as mpf

start = '1990-01-01'
end = dt.datetime.now()
stock_code = '^GSPC'
df = yf.download(stock_code, start, end, interval='1d')

# 何日間で最大最小の値を保持
shortTerm = 20
longTerm = 60

# 損切り率と利確の日数
stopLoss = 0.95
rikaku_day = 80

# judge U trend or Down trend by DC
buy_position = False # 1 means entered and 0 means not already entered
sell_position = False

# 買った（売った）後に経過した日数、損切りラインを保持
buy_dates = 0
sell_dates = 0
buy_stopLine = 0
sell_stopLine = 0
counter = 1
percentChange = []
# assets = []

# chek the highest price in the past {term} times
df['Highest'+str(shortTerm)] = df.iloc[:, 4].rolling(window=shortTerm).max()
# chek the highest price in the past {term} times
df['Lowest'+str(shortTerm)] = df.iloc[:, 4].rolling(window=shortTerm).min()

# chek the highest price in the past {term} times
df['Highest'+str(longTerm)] = df.iloc[:, 4].rolling(window=longTerm).max()
# chek the highest price in the past {term} times
df['Lowest'+str(longTerm)] = df.iloc[:, 4].rolling(window=longTerm).min()

# df.iloc[:,1]
# df['Highest'+str(longTerm)][:65]
# df['Lowest'+str(longTerm)][:65]

"""
メインループ
基本戦略
過去longTerm間の調整済み終値の最高値をその日の調整済み終値が更新したら購入or空売り
損切り率は5%。80日後に利確する。
最終日にまだ保持していた場合捌く
"""
# for i in range(1, len(df)):
for i in range(1,len(df)):
#     print(buy_position, sell_position, buy_dates, sell_dates, buy_stopLine, sell_stopLine, 'Adj Close:{}'.format(df['Adj Close'][i]))
#     if counter == 100:
#         break
    
    shortHighest = df['Highest'+str(shortTerm)][i-1]
    shortLowest = df['Lowest'+str(shortTerm)][i-1]
    longHighest = df['Highest'+str(longTerm)][i-1]
    longLowest = df['Lowest'+str(longTerm)][i-1] 
    # high_price = df['High'][i]
    # low_price = df['Low'][i]
    close = df['Adj Close'][i]
    
    # avoid NaN data 
    # 買いトレンド
    if (np.isnan(longHighest)) == False:
        if (close > longHighest and buy_position == False):
            print('Up trend')
            buy_position = True
            buy_price = close
            buy_stopLine = close * stopLoss
            print('Date:'+str(i),'Buy at the price {}'.format(buy_price))
    
    # 売りトレンド
    if (np.isnan(longLowest)) == False:
        if (close < longLowest and sell_position == False):
            print('Down trend')
            sell_position = True
            sell_price = close
            sell_stopLine = close * stopLoss
            print('Date:'+str(i),'Short Sell at the price {}'.format(sell_price))

    # 損切り
    if buy_position == True and close < buy_price*stopLoss:
        buy_position = False
        percent = (close/buy_price - 1) * 100
        percentChange.append(percent)
        buy_dates = 0
        print('Date:'+str(i),'Stop Loss Buy at the price {}'.format(close))
    if sell_position == True and close > (sell_price + sell_price*(1-stopLoss)):
        sell_position = False
        percent = (sell_price/close - 1) * 100
        percentChange.append(percent)
        sell_dates = 0
        print('Date:'+str(i),'Stop Loss Sell at the price {}'.format(close))

    # 利確
    if buy_dates == 80:
        buy_position = False
        percent = (close/buy_price - 1) * 100
        percentChange.append(percent)
        buy_dates = 0
        print('Date:'+str(i),'Secure Profit Buy at the price {}'.format(close))
    if sell_dates == 80:
        sell_position = False
        percent = (sell_price/close - 1) * 100
        percentChange.append(percent)
        sell_dates = 0
        print('Date:'+str(i),'Secure Profit Sell at the price {}'.format(close))
        
    # 損切りラインの更新
    # if buy_position = 

    #  最終日にまだ持ってたら利確する
    if (counter == df['Adj Close'].count() - 1):
        if buy_position == True:
            buy_position = False
            percent = (close / buy_price - 1) * 100
            percentChange.append(percent)
            buy_dates = 0
            print('Date:'+str(i),'Last Day Buy at the price {}'.format(close))
        if sell_position == True:
            sell_position = False
            percent = (sell_price/close - 1) * 100
            percentChange.append(percent)
            sell_dates = 0
            print('Date:'+str(i),'Last Day Sell at the price {}'.format(close))

    # 買ってからの日数を更新する
    if buy_position == True:
        buy_dates += 1
    if sell_position == True:
        sell_dates += 1
    counter += 1



print(percentChange)

# statistic
gains = 0
numGains = 0
losses = 0
numLosses = 0
total_return = 1

for i in percentChange:
    if i > 0:
        numGains += 1
        gains += i
    else:
        numLosses += 1
        losses += i
    total_return = total_return * ((i / 100) + 1)

total_return = round((total_return - 1)*100, 2)

if numGains > 0:
    average_gain = gains / numGains
    max_return = max(percentChange)
else:
    average_gain = 0
    max_return = 'unknown'
    
if numLosses > 0:
    average_loss = losses / numLosses
    max_loss = min(percentChange)
    risk_reward_retio = - average_gain / average_loss
else:
    average_loss = 0
    max_loss = 'unknown'
    risk_reward_retio = 'inf'
    
if numGains > 0 or numLosses > 0:
    batting_ratio = numGains / (numGains + numLosses)
else:
    batting_ratio = 0
    
print('The period is from {} up to {}'.format(df.index[0], df.index[-1]))
print('Trades: {}'.format(numGains+numLosses))
print('Total return: {}%'.format(total_return))
print('Average Gain: {}'.format(average_gain))
print('Average Loss: {}'.format(average_loss))
print('Max Return: {}'.format(max_return))
print('Max Loss: {}'.format(max_loss))
print('Gain/Loss Ratio: {}'.format(risk_reward_retio))
print('Batting Average: {}'.format(batting_ratio))
# Out:
# [*********************100%***********************]  1 of 1 completed
# Up trend
# Date:71 Buy at the price 344.3399963378906
# Down trend
# Date:150 Short Sell at the price 334.42999267578125
# Date:151 Secure Profit Buy at the price 334.8299865722656
# Date:230 Secure Profit Sell at the price 317.95001220703125
# Up trend
# Date:233 Buy at the price 324.1000061035156
# Date:313 Secure Profit Buy at the price 375.2200012207031
# Up trend
# Date:315 Buy at the price 379.5
# Date:395 Secure Profit Buy at the price 380.9599914550781
# Up trend
# Date:403 Buy at the price 390.6199951171875
# Down trend
# Date:480 Short Sell at the price 376.1400146484375
# Date:483 Secure Profit Buy at the price 376.54998779296875
# Date:500 Stop Loss Sell at the price 396.82000732421875
# Up trend
# Date:501 Buy at the price 399.3299865722656
# Down trend
# Date:566 Short Sell at the price 403.5
# Date:581 Secure Profit Buy at the price 410.17999267578125
# Up trend
# Date:596 Buy at the price 418.489990234375
# Date:646 Secure Profit Sell at the price 410.92999267578125
# Date:676 Secure Profit Buy at the price 417.9800109863281
# Up trend
# Date:683 Buy at the price 425.2699890136719
# Down trend
# Date:697 Short Sell at the price 410.4700012207031
# Date:702 Stop Loss Buy at the price 402.6600036621094
# Up trend
# Date:732 Buy at the price 426.6499938964844
# Date:737 Stop Loss Sell at the price 431.3500061035156
# Date:812 Secure Profit Buy at the price 451.8900146484375
# Up trend
# Date:918 Buy at the price 456.0400085449219
# Date:998 Secure Profit Buy at the price 463.92999267578125
# Up trend
# Date:1008 Buy at the price 470.5400085449219
# Down trend
# Date:1071 Short Sell at the price 460.5799865722656
# Date:1074 Stop Loss Buy at the price 445.54998779296875
# Date:1151 Secure Profit Sell at the price 452.6099853515625
# Up trend
# Date:1169 Buy at the price 465.010009765625
# Down trend
# Date:1238 Short Sell at the price 450.0899963378906
# Date:1249 Secure Profit Buy at the price 445.45001220703125
# Up trend
# Date:1283 Buy at the price 470.3900146484375
# Date:1287 Stop Loss Sell at the price 472.7900085449219
# Date:1363 Secure Profit Buy at the price 528.5900268554688
# Up trend
# Date:1364 Buy at the price 528.6099853515625
# Date:1444 Secure Profit Buy at the price 582.77001953125
# Up trend
# Date:1445 Buy at the price 584.2000122070312
# Date:1525 Secure Profit Buy at the price 601.8099975585938
# Up trend
# Date:1536 Buy at the price 624.219970703125
# Date:1616 Secure Profit Buy at the price 678.4199829101562
# Up trend
# Date:1618 Buy at the price 678.510009765625
# Down trend
# Date:1652 Short Sell at the price 629.7999877929688
# Date:1652 Stop Loss Buy at the price 629.7999877929688
# Date:1666 Stop Loss Sell at the price 662.489990234375
# Up trend
# Date:1695 Buy at the price 680.5399780273438
# Date:1775 Secure Profit Buy at the price 748.4099731445312
# Up trend
# Date:1777 Buy at the price 759.5
# Down trend
# Date:1840 Short Sell at the price 737.6500244140625
# Date:1847 Stop Loss Sell at the price 774.6099853515625
# Date:1857 Secure Profit Buy at the price 827.760009765625
# Up trend
# Date:1861 Buy at the price 837.6599731445312
# Date:1941 Secure Profit Buy at the price 930.8699951171875
# Up trend
# Date:1961 Buy at the price 960.4600219726562
# Down trend
# Date:1978 Short Sell at the price 876.989990234375
# Date:1978 Stop Loss Buy at the price 876.989990234375
# Date:1979 Stop Loss Sell at the price 921.8499755859375
# Up trend
# Date:2006 Buy at the price 983.7899780273438
# Date:2019 Stop Loss Buy at the price 932.7000122070312
# Up trend
# Date:2042 Buy at the price 985.489990234375
# Date:2122 Secure Profit Buy at the price 1094.02001953125
# Down trend
# Date:2136 Short Sell at the price 1077.010009765625
# Up trend
# Date:2143 Buy at the price 1132.8800048828125
# Date:2143 Stop Loss Sell at the price 1132.8800048828125
# Down trend
# Date:2171 Short Sell at the price 1072.1199951171875
# Date:2171 Stop Loss Buy at the price 1072.1199951171875
# Up trend
# Date:2234 Buy at the price 1111.5999755859375
# Date:2237 Stop Loss Sell at the price 1133.8499755859375
# Date:2314 Secure Profit Buy at the price 1236.1600341796875
# Up trend
# Date:2319 Buy at the price 1282.72998046875
# Date:2399 Secure Profit Buy at the price 1372.7099609375
# Up trend
# Date:2400 Buy at the price 1380.9599609375
# Date:2423 Stop Loss Buy at the price 1305.3299560546875
# Down trend
# Date:2458 Short Sell at the price 1280.4100341796875
# Date:2484 Stop Loss Sell at the price 1362.9300537109375
# Up trend
# Date:2494 Buy at the price 1396.06005859375
# Down trend
# Date:2561 Short Sell at the price 1346.0899658203125
# Date:2574 Secure Profit Buy at the price 1401.68994140625
# Date:2579 Stop Loss Sell at the price 1458.469970703125
# Up trend
# Date:2582 Buy at the price 1493.8699951171875
# Date:2600 Stop Loss Buy at the price 1356.56005859375
# Up trend
# Date:2660 Buy at the price 1492.9200439453125
# Down trend
# Date:2721 Short Sell at the price 1408.989990234375
# Date:2721 Stop Loss Buy at the price 1408.989990234375
# Date:2801 Secure Profit Sell at the price 1373.469970703125
# Down trend
# Date:2814 Short Sell at the price 1255.27001953125
# Up trend
# Date:2873 Buy at the price 1284.989990234375
# Date:2893 Stop Loss Buy at the price 1219.8699951171875
# Date:2894 Secure Profit Sell at the price 1214.3599853515625
# Down trend
# Date:2920 Short Sell at the price 1171.6500244140625
# Date:3000 Secure Profit Sell at the price 1142.6600341796875
# Up trend
# Date:3010 Buy at the price 1170.3499755859375
# Date:3046 Stop Loss Buy at the price 1100.6400146484375
# Down trend
# Date:3050 Short Sell at the price 1094.43994140625
# Date:3069 Stop Loss Sell at the price 1153.8399658203125
# Down trend
# Date:3107 Short Sell at the price 1076.3199462890625
# Date:3187 Secure Profit Sell at the price 937.4299926757812
# Down trend
# Date:3220 Short Sell at the price 785.280029296875
# Date:3224 Stop Loss Sell at the price 835.3200073242188
# Up trend
# Date:3253 Buy at the price 933.760009765625
# Date:3272 Stop Loss Buy at the price 884.25
# Down trend
# Date:3295 Short Sell at the price 861.4000244140625
# Up trend
# Date:3355 Buy at the price 911.3699951171875
# Date:3355 Stop Loss Sell at the price 911.3699951171875
# Date:3435 Secure Profit Buy at the price 990.510009765625
# Up trend
# Date:3447 Buy at the price 1021.989990234375
# Date:3527 Secure Profit Buy at the price 1094.0400390625
# Up trend
# Date:3529 Buy at the price 1109.47998046875
# Down trend
# Date:3587 Short Sell at the price 1093.949951171875
# Date:3596 Stop Loss Sell at the price 1150.5699462890625
# Date:3609 Secure Profit Buy at the price 1140.5999755859375
# Down trend
# Date:3620 Short Sell at the price 1087.1199951171875
# Date:3640 Stop Loss Sell at the price 1142.1800537109375
# Down trend
# Date:3672 Short Sell at the price 1084.0699462890625
# Up trend
# Date:3720 Buy at the price 1131.5
# Date:3723 Stop Loss Sell at the price 1142.050048828125
# Date:3800 Secure Profit Buy at the price 1174.0699462890625
# Up trend
# Date:3826 Buy at the price 1222.1199951171875
# Down trend
# Date:3854 Short Sell at the price 1162.050048828125
# Date:3855 Stop Loss Buy at the price 1142.6199951171875
# Up trend
# Date:3897 Buy at the price 1206.5799560546875
# Date:3915 Stop Loss Sell at the price 1222.2099609375
# Down trend
# Date:3975 Short Sell at the price 1196.3900146484375
# Date:3977 Secure Profit Buy at the price 1195.9000244140625
# Up trend
# Date:4006 Buy at the price 1242.800048828125
# Date:4009 Stop Loss Sell at the price 1261.22998046875
# Date:4086 Secure Profit Buy at the price 1305.3299560546875
# Up trend
# Date:4087 Buy at the price 1307.25
# Down trend
# Date:4129 Short Sell at the price 1270.3199462890625
# Date:4146 Stop Loss Buy at the price 1237.43994140625
# Up trend
# Date:4192 Buy at the price 1295.4300537109375
# Date:4209 Secure Profit Sell at the price 1299.5400390625
# Date:4272 Secure Profit Buy at the price 1409.8399658203125
# Up trend
# Date:4276 Buy at the price 1425.489990234375
# Down trend
# Date:4327 Short Sell at the price 1387.1700439453125
# Date:4356 Secure Profit Buy at the price 1452.8499755859375
# Up trend
# Date:4357 Buy at the price 1468.3299560546875
# Date:4357 Stop Loss Sell at the price 1468.3299560546875
# Down trend
# Date:4428 Short Sell at the price 1482.6600341796875
# Date:4437 Secure Profit Buy at the price 1497.489990234375
# Up trend
# Date:4478 Buy at the price 1557.5899658203125
# Date:4478 Stop Loss Sell at the price 1557.5899658203125
# Date:4501 Stop Loss Buy at the price 1475.6199951171875
# Down trend
# Date:4511 Short Sell at the price 1416.77001953125
# Date:4521 Stop Loss Sell at the price 1507.3399658203125
# Down trend
# Date:4542 Short Sell at the price 1390.18994140625
# Up trend
# Date:4617 Buy at the price 1397.8399658203125
# Date:4622 Secure Profit Sell at the price 1413.9000244140625
# Date:4656 Stop Loss Buy at the price 1317.9300537109375
# Down trend
# Date:4658 Short Sell at the price 1314.2900390625
# Date:4738 Secure Profit Sell at the price 946.4299926757812
# Down trend
# Date:4742 Short Sell at the price 896.780029296875
# Date:4748 Stop Loss Sell at the price 954.0900268554688
# Down trend
# Date:4762 Short Sell at the price 806.5800170898438
# Date:4765 Stop Loss Sell at the price 851.8099975585938
# Down trend
# Date:4824 Short Sell at the price 770.0499877929688
# Date:4845 Stop Loss Sell at the price 822.9199829101562
# Up trend
# Date:4871 Buy at the price 873.6400146484375
# Date:4951 Secure Profit Buy at the price 1026.1300048828125
# Up trend
# Date:4953 Buy at the price 1028.0
# Date:5033 Secure Profit Buy at the price 1096.0799560546875
# Up trend
# Date:5036 Buy at the price 1118.02001953125
# Down trend
# Date:5065 Short Sell at the price 1063.1099853515625
# Date:5067 Stop Loss Buy at the price 1056.739990234375
# Date:5082 Stop Loss Sell at the price 1118.31005859375
# Up trend
# Date:5089 Buy at the price 1150.239990234375
# Down trend
# Date:5138 Short Sell at the price 1071.5899658203125
# Date:5138 Stop Loss Buy at the price 1071.5899658203125
# Date:5188 Stop Loss Sell at the price 1125.8599853515625
# Up trend
# Date:5222 Buy at the price 1142.7099609375
# Date:5302 Secure Profit Buy at the price 1285.9599609375
# Up trend
# Date:5304 Buy at the price 1293.239990234375
# Date:5384 Secure Profit Buy at the price 1342.0799560546875
# Down trend
# Date:5408 Short Sell at the price 1265.4200439453125
# Date:5420 Stop Loss Sell at the price 1339.6700439453125
# Down trend
# Date:5441 Short Sell at the price 1254.050048828125
# Up trend
# Date:5502 Buy at the price 1284.5899658203125
# Date:5505 Stop Loss Buy at the price 1218.280029296875
# Date:5521 Secure Profit Sell at the price 1161.7900390625
# Up trend
# Date:5552 Buy at the price 1292.0799560546875
# Date:5632 Secure Profit Buy at the price 1369.0999755859375
# Down trend
# Date:5638 Short Sell at the price 1338.3499755859375
# Up trend
# Date:5695 Buy at the price 1390.989990234375
# Date:5700 Stop Loss Sell at the price 1405.8699951171875
# Down trend
# Date:5760 Short Sell at the price 1394.530029296875
# Date:5775 Secure Profit Buy at the price 1415.949951171875
# Up trend
# Date:5797 Buy at the price 1462.4200439453125
# Date:5799 Stop Loss Sell at the price 1466.469970703125
# Date:5877 Secure Profit Buy at the price 1593.6099853515625
# Up trend
# Date:5878 Buy at the price 1597.5699462890625
# Date:5958 Secure Profit Buy at the price 1656.9599609375
# Up trend
# Date:5976 Buy at the price 1725.52001953125
# Date:6056 Secure Profit Buy at the price 1819.199951171875
# Up trend
# Date:6058 Buy at the price 1848.3800048828125
# Down trend
# Date:6070 Short Sell at the price 1741.8900146484375
# Date:6070 Stop Loss Buy at the price 1741.8900146484375
# Date:6078 Stop Loss Sell at the price 1829.8299560546875
# Up trend
# Date:6087 Buy at the price 1854.2900390625
# Date:6167 Secure Profit Buy at the price 1962.6099853515625
# Up trend
# Date:6173 Buy at the price 1973.3199462890625
# Down trend
# Date:6244 Short Sell at the price 1906.1300048828125
# Date:6247 Stop Loss Buy at the price 1862.489990234375
# Up trend
# Date:6259 Buy at the price 2018.050048828125
# Date:6259 Stop Loss Sell at the price 2018.050048828125
# Date:6339 Secure Profit Buy at the price 2104.5
# Up trend
# Date:6340 Buy at the price 2117.389892578125
# Date:6420 Secure Profit Buy at the price 2108.580078125
# Down trend
# Date:6423 Short Sell at the price 2057.639892578125
# Date:6503 Secure Profit Sell at the price 2018.93994140625
# Up trend
# Date:6512 Buy at the price 2109.7900390625
# Down trend
# Date:6555 Short Sell at the price 1990.260009765625
# Date:6555 Stop Loss Buy at the price 1990.260009765625
# Up trend
# Date:6612 Buy at the price 2063.949951171875
# Date:6625 Stop Loss Sell at the price 2094.340087890625
# Down trend
# Date:6673 Short Sell at the price 2037.4100341796875
# Date:6684 Stop Loss Sell at the price 2152.139892578125
# Date:6692 Secure Profit Buy at the price 2175.030029296875
# Up trend
# Date:6702 Buy at the price 2182.8701171875
# Down trend
# Date:6763 Short Sell at the price 2111.719970703125
# Date:6782 Secure Profit Buy at the price 2204.659912109375
# Up trend
# Date:6788 Buy at the price 2241.35009765625
# Date:6788 Stop Loss Sell at the price 2241.35009765625
# Date:6868 Secure Profit Buy at the price 2360.159912109375
# Up trend
# Date:6890 Buy at the price 2399.2900390625
# Date:6970 Secure Profit Buy at the price 2446.300048828125
# Up trend
# Date:6978 Buy at the price 2488.110107421875
# Date:7058 Secure Profit Buy at the price 2723.989990234375
# Up trend
# Date:7059 Buy at the price 2743.14990234375
# Date:7082 Stop Loss Buy at the price 2581.0
# Up trend
# Date:7165 Buy at the price 2779.030029296875
# Date:7245 Secure Profit Buy at the price 2923.429931640625
# Down trend
# Date:7251 Short Sell at the price 2785.679931640625
# Date:7331 Secure Profit Sell at the price 2731.610107421875
# Up trend
# Date:7342 Buy at the price 2792.669921875
# Date:7422 Secure Profit Buy at the price 2917.75
# Up trend
# Date:7424 Buy at the price 2954.179931640625
# Date:7504 Secure Profit Buy at the price 2966.14990234375
# Up trend
# Date:7512 Buy at the price 3010.2900390625
# Date:7592 Secure Profit Buy at the price 3373.22998046875
# Down trend
# Date:7597 Short Sell at the price 2978.760009765625
# Date:7601 Stop Loss Sell at the price 3130.1201171875
# Down trend
# Date:7604 Short Sell at the price 2746.56005859375
# Date:7640 Stop Loss Sell at the price 2939.510009765625
# Up trend
# Date:7662 Buy at the price 3055.72998046875
# Date:7742 Secure Profit Buy at the price 3236.919921875
# Up trend
# Date:7779 Buy at the price 3585.14990234375
# Date:7839 Last Day Buy at the price 3916.3798828125
# [-2.761808057955928, 5.183198564565283, 15.772907792189317, 0.38471448091650373, -3.6019680252153186, -5.2114289335428605, 2.7170526803281136, -1.8080920858077665, -0.12186175534598664, -5.31661907392097, -4.840617732088703, 5.9158610366878195, 1.7301078815505244, -5.310923683032021, 1.7608982299655684, -4.206360540163945, -4.80128847834449, 12.372714214720105, 10.245745574341969, 3.014376067031277, 8.682838542634276, -7.17896880983111, -4.934414545620713, 9.972962251816519, -4.771428413839185, 8.987493056698481, 11.12742938196638, -8.690630513370557, -4.866299998874435, -5.193178113356678, 11.01279874705412, -4.931678101509684, -5.363322638209167, -5.444281148116614, 11.20547511060288, 7.014724988018783, -5.476625465047458, -6.05460414542679, 0.40326938499843923, -7.705335532457647, -9.19155863443567, -5.621871985129023, 2.5861518845633036, -5.067743376375244, 3.3688555842725565, 2.537061712776789, -5.956334634227645, -5.148029724540926, 14.816034765096076, -5.990515920675343, -5.302219975992772, -5.482951048514573, 8.683631793063507, 7.049975979862744, -4.921038942465361, 2.804917228343262, -4.820611112482675, -5.076844276532078, 3.7622577365499232, -6.505089542567943, -4.9222240066861485, -0.8851408136719363, -5.141010507553434, 5.031373090588787, -5.340222497131386, -2.2484949978545554, 8.831809311636096, 1.9193390019570877, -5.527362005706582, 1.9859319807135734, -4.810632662310632, -5.262615483013533, -6.008594500429987, -1.676927830709829, -5.716671011225549, 38.86817294818516, -6.006770424744767, -5.3098672941601315, -6.424682376799162, 17.45455653101451, 6.622563818549376, -5.481120930425531, -4.936025820209499, -6.837705616376333, -4.820316934374713, 12.535989437116225, 3.7765585807056024, -5.542409516102531, -5.161953486153326, 7.941194765284232, 5.960932926041784, -4.8027214298447145, 1.7944026278215341, -4.9056539065547415, 8.970742841593315, 3.717522026900455, 5.429084019904562, -5.761260668967605, -4.805907844893853, 5.8415859443341045, -5.616421009837225, -5.545949864340782, 4.283835835591709, -0.41606954316751876, 1.9168450917326219, -5.665494057882126, -4.969588211904363, -5.330966578617646, 5.38191723408461, 0.9982176562089773, -5.783573351110006, 5.300814655299191, 1.9593300101389044, 9.480283131718537, -5.9110842686799225, 5.196054048407839, 1.9794122181580942, 4.478870816248182, 0.4051875979157904, 12.056643602331452, -4.835600608128621, -6.5640174903591975, 5.929514144389669, 9.238943684117995]
# The period is from 1990-01-02 00:00:00 up to 2021-02-11 00:00:00
# Trades: 124
# Total return: 1.5%
# Average Gain: 6.757162218737581
# Average Loss: -5.097817684043312
# Max Return: 38.86817294818516
# Max Loss: -9.19155863443567
# Gain/Loss Ratio: 1.325500956985611
# Batting Average: 0.45161290322580644

# %%
"""
メインループ
比較対象：最初の日に買って、最後の日に売る
"""

percentChange = []
counter = 1
print(df.index[:5])

for i in range(1,len(df)):
#     print(counter)
#     print(counter,df.index[i])
#     print(buy_position, sell_position, buy_dates, sell_dates, buy_stopLine, sell_stopLine, 'Adj Close:{}'.format(df['Adj Close'][i]))
#     if counter == 100:
#         break
    close = df['Adj Close'][i]
    
    if i == 1:
        buy_price = close
        print('Buy at the price {}'.format(buy_price))
        
    if (counter == df['Adj Close'].count() - 1):
        percent = (close/buy_price - 1) * 100
        percentChange.append(percent)
        print('Sell at the price {}'.format(close))
        
    counter += 1


print(percentChange)

# statistic
gains = 0
numGains = 0
losses = 0
numLosses = 0
total_return = 1

for i in percentChange:
    if i > 0:
        numGains += 1
        gains += i
    else:
        numLosses += 1
        losses += i
    total_return = total_return * ((i / 100) + 1)

total_return = round((total_return - 1)*100, 2)

if numGains > 0:
    average_gain = gains / numGains
    max_return = max(percentChange)
else:
    average_gain = 0
    max_return = 'unknown'
    
if numLosses > 0:
    average_loss = losses / numLosses
    max_loss = min(percentChange)
    risk_reward_retio = - average_gain / average_loss
else:
    average_loss = 0
    max_loss = 'unknown'
    risk_reward_retio = 'inf'
    
if numGains > 0 or numLosses > 0:
    batting_ratio = numGains / (numGains + numLosses)
else:
    batting_ratio = 0
    
print('The period is from {} up to {}'.format(df.index[0], df.index[-1]))
print('Trades: {}'.format(numGains+numLosses))
print('Total return: {}%'.format(total_return))
print('Average Gain: {}'.format(average_gain))
print('Average Loss: {}'.format(average_loss))
print('Max Return: {}'.format(max_return))
print('Max Loss: {}'.format(max_loss))
print('Gain/Loss Ratio: {}'.format(risk_reward_retio))
print('Batting Average: {}'.format(batting_ratio))
# Out:
# DatetimeIndex(['1990-01-02', '1990-01-03', '1990-01-04', '1990-01-05',
#                '1990-01-08'],
#               dtype='datetime64[ns]', name='Date', freq=None)
# Buy at the price 358.760009765625
# Sell at the price 3748.489990234375
# [944.8461055297754]
# The period is from 1990-01-02 00:00:00 up to 2021-02-01 00:00:00
# Trades: 1
# Total return: 944.85%
# Average Gain: 944.8461055297754
# Average Loss: 0
# Max Return: 944.8461055297754
# Max Loss: unknown
# Gain/Loss Ratio: inf
# Batting Average: 1.0
